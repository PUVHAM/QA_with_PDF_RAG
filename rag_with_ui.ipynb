# %% [markdown]
# <a href="https://colab.research.google.com/github/PUVHAM/QA_with_PDF_RAG/blob/feature%2Fproject_ver1/rag_with_ui.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Install the required dependencies**

# %%
# !pip install -q -r requirements.txt
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.4/309.4 kB 32.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.6/974.6 kB 64.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 83.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 15.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 65.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.8/332.8 kB 34.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.4/127.4 kB 15.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 559.5/559.5 kB 50.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 14.0 MB/s eta 0:00:00
# ...

# %%
# !pip install -q pypdf
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 9.5 MB/s eta 0:00:00

# %% [markdown]
# # **Run app.py**

# %%
# !python app.py
# Out:
# 2024-07-01 22:30:33 - Created default config file at /content/.chainlit/config.toml
# 2024-07-01 22:30:33 - Created default translation directory at /content/.chainlit/translations
# 2024-07-01 22:30:33 - Created default translation file at /content/.chainlit/translations/en-US.json
# 2024-07-01 22:30:46.734142: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-01 22:30:46.734196: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-01 22:30:46.856559: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# # **Using Ngrok to Expose Local Server to the Internet**

# %% [markdown]
# 1. Go to https://ngrok.com/, create an account and login information.
# 2. Go to Your Authtoken, copy your authtoken.
# 3. Return to Google Colab and run ngrok using the following command:
# * !pip install pyngrok -q
# * from pyngrok import ngrok
# * !ngrok config add-authtoken **"your-authtoken"**
# * public_url = ngrok.connect(8000).public_url
# * print(public_url)
# 4. Then, when you finish running the command !chainlit run app.py and it displays http://localhost:8000, click on the public_url printed above

# %%
# !pip install pyngrok -q
from pyngrok import ngrok

# %%
# !ngrok config add-authtoken

# %%
public_url = ngrok.connect(8000).public_url
print(public_url)

# %%
# Run the program
# !chainlit run app.py
